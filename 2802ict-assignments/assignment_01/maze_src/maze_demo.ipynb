# %%
from maze import Maze
from common import NoSolutionError

# %%
m = Maze("/home/roman/learning-ml/2802ict-assignments/assignment_01/maze_src/cnn_compatible_maps/0.txt")
# m = Maze("/home/roman/learning-ml/2802ict-assignments/assignment_01/maze_src/maze3.txt")

m.output_image("huh.png")

# m.reset_stats()
# try:
#     m.astar_solve()
# except NoSolutionError:
#     pass
# except Exception as e:
#     raise e

# m.print()
