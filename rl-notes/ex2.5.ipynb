# %%
import numpy as np
from tqdm import tqdm

# %%
float_formatter = "{:.2f}".format
np.set_printoptions(formatter={'float_kind':float_formatter})

# %% [markdown]
# Important notes:
#
# - N is per-action
# - For the running average, N starts at 1, such that the initial value is fully replaced

# %%
def simulate(epsilon = 0.1, alpha = 0.01, steps = 1000):
    avg_reward = np.zeros((steps)) # average reward for each step

    n = 1
    for run in tqdm(range(2000)):
        q = np.random.normal(0, 1, (10))
        Q = np.zeros((10))
        N = np.ones((10))
        for i in range(steps):
            # q = q + np.random.normal(0, 0.01, (10))

            # print(q, Q)

            if np.random.random() >= epsilon: # take greedy action
                maxQ = Q.max()
                index = np.random.choice(np.flatnonzero(Q == maxQ))
            else: # exploe
                index = np.random.randint(0,10)
            
            reward = np.random.normal(q[index], 1)

            Q[index] = Q[index] + (1/N[index]) * (reward - Q[index])
            N[index] = N[index] + 1

            avg_reward[i] = avg_reward[i] + (1/n) * (reward - avg_reward[i])
        n += 1
    
    return avg_reward

# %%
greedy
# Out:
# 1598890

# %%
import plotly.express as px

data = {'0.1': simulate(epsilon=0.1),'0.01': simulate(epsilon=0.01),'0': simulate(epsilon=0.0), 'x': np.arange(1, 1001)}
# Out:
# 100%|██████████| 2000/2000 [00:19<00:00, 102.42it/s]
# 100%|██████████| 2000/2000 [00:20<00:00, 99.65it/s]
# 100%|██████████| 2000/2000 [00:20<00:00, 99.24it/s]

# %%
data['0.1']
# Out:
# 1000

# %%
px.line(data, x='x', y=['0.1', '0.01', '0'])
