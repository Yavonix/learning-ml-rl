# %%
from jax import numpy as jnp
from flax import nnx

# %%
rngs = nnx.Rngs(42)

# %%
a = jnp.array([[1,2,3,4],[10,11,12,13],[30,31,32,33],[40,41,42,43]])
indices = jnp.array([[1,0],[2,3]])

a[indices]

# %%
a[indices]
a.take(indices, axis=0)

# %%
import torch

torch_a = torch.tensor([[1,2,3,4],[10,11,12,13],[30,31,32,33],[40,41,42,43]])
torch_indices = torch.tensor([[1,0],[2,3]])

torch.take(torch_a, torch_indices) # does not have axis arg
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 indices = torch.tensor([[1,0],[2,3]])
#       6 # a[indices]
# ----> 7 torch.take(a, indices, dim=0)
#
# TypeError: take() got an unexpected keyword argument 'dim'
