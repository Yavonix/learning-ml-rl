# %% [markdown]
# Numpy advanced indexing triggered when selection object is non-tuple sequence object or ndarray or tuple with non-tuple sequence object or ndarray
#
# Numpy advanced indices are always broadcast to be the same shape and iterated as one
# - ie numpy first makes those index arrays the same shape by broadcasting, then walks through them element-by-element together
# - it zips the indices together

# %% [markdown]
# ### Basics

# %%
import numpy as np

x = np.array([
    [10, 11, 12],
    [20, 21, 22],
    [30, 31, 32]
])

x[[0, 1, 2], [2, 1, 0]] # selects (0, 2), (1, 1), (2, 0)
# Out:
# array([12, 21, 30])

# %% [markdown]
# ### Broadcasting

# %%
rows = np.array([[0], [1], [2]])   # shape (3, 1)
cols = np.array([[0, 1, 2]])       # shape (1, 3)
x[rows, cols]
# Out:
# array([[10, 11, 12],
#        [20, 21, 22],
#        [30, 31, 32]])

# %% [markdown]
# up to https://numpy.org/doc/stable/user/basics.indexing.html#:~:text=Example,-From%20a

# %% [markdown]
# todo squeeze and reshape
# also fix up deep and bidirectional RNN anki notes
